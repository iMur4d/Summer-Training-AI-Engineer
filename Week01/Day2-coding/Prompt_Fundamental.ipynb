# %% [markdown]
# # **Prompt Fundamental**
#
# **The core task:** "Write an excuse email message to my manager."
#
#  Write 5 different prompts for the SAME task:
#
#   - Basic (very simple)
#
#   - Improved
#
#   - Detailed
#
#   - Creative
#
#   - With clear constraints

# %% [markdown]
# ## Setup Enviroment

# %%
# %pip install python-dotenv
# %pip install google-genai
# Out:
# Requirement already satisfied: python-dotenv in c:\Users\Dvs\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (1.2.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: google-genai in c:\Users\Dvs\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (2.10.0)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in c:\Users\Dvs\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from google-genai) (4.14.1)
# Requirement already satisfied: google-auth<3.0.0,>=2.48.1 in c:\Users\Dvs\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from google-auth[requests]<3.0.0,>=2.48.1->google-genai) (2.55.1)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in c:\Users\Dvs\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.12.5 in c:\Users\Dvs\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from google-genai) (2.13.4)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in c:\Users\Dvs\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from google-genai) (2.34.2)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in c:\Users\Dvs\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from google-genai) (9.1.4)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in c:\Users\Dvs\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from google-genai) (16.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in C:\Users\Dvs\AppData\Roaming\Python\Python314\site-packages (from google-genai) (4.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\Users\Dvs\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from google-genai) (1.9.0)
# Requirement already satisfied: sniffio in c:\Users\Dvs\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from google-genai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in c:\Users\Dvs\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.18)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\Users\Dvs\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in c:\Users\Dvs\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (49.0.0)
# Requirement already satisfied: certifi in c:\Users\Dvs\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in c:\Users\Dvs\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\Users\Dvs\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\Users\Dvs\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pydantic<3.0.0,>=2.12.5->google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\Users\Dvs\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pydantic<3.0.0,>=2.12.5->google-genai) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\Users\Dvs\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pydantic<3.0.0,>=2.12.5->google-genai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\Dvs\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\Users\Dvs\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.7.0)
# Requirement already satisfied: cffi>=2.0.0 in c:\Users\Dvs\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (2.0.0)
# Requirement already satisfied: pycparser in c:\Users\Dvs\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\Users\Dvs\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (0.6.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from dotenv import load_dotenv
from google import genai
from google.genai import types

load_dotenv()
gemini_key = os.getenv("GEMINI_API_KEY")

config = types.GenerateContentConfig(
    temperature= 0.7,
    max_output_tokens= 300,
)

client =genai.Client(api_key=gemini_key)

# %% [markdown]
# ## Basic Prompting

# %%
# Basic Prompting
basic_prompt = "write a excuse message" # Only Task

basic_response = client.models.generate_content(
    model='gemini-3.1-flash-lite',
    contents= basic_prompt,
    config=config
)

print(f'AI Response With basic prompt:\n {"-"*30}\n{basic_response.text}\n {"-"*30}')
# Out:
# AI Response With basic prompt:
#  ------------------------------
# To give you the best excuse, I need to know **who you are sending it to** and **what you are trying to get out of.**
#
# Here are a few templates based on the most common situations. Choose the one that fits best:
#
# ### 1. For a Work/Professional Meeting (Running Late)
# *   "Hi [Name], please accept my apologies, but I’ve been held up by [an unexpected issue/traffic/a prior meeting running over]. I’m on my way now and should be there by [Time]. So sorry for the inconvenience!"
#
# ### 2. For Canceling Plans (Friends/Social)
# *   "Hey! I am so sorry, but I’m not going to be able to make it tonight. I’ve been feeling really run down/have had a crazy week and I think I just need to stay in and recharge. Can we reschedule for [Day] instead?"
#
# ### 3. For Missing a Deadline
# *   "Hi [Name], I’m writing to apologize for the delay on [Project]. I’ve hit a few unexpected roadblocks that took longer than anticipated to resolve. I’m working hard to get this to you by [Time/Day]. Thank you for your patience."
#
# ### 4. The "Vague but Polite" (When you just want to say no)
# *   "Hi [Name], thank you so much for
#  ------------------------------

# %% [markdown]
# ## Improved Prompting

# %%
# Improved Prompting

# Here I will increase the specificity of the prompt.
Improved_prompt = "You are a professional employee. Write a short excuse message to your manager." # Putting "Role", "Task", and "To Whom"

Improved_response = client.models.generate_content(
    model='gemini-3.1-flash-lite',
    contents= Improved_prompt,
    config=config
)

print(f'AI Response With improved prompt:\n {"-"*30}\n{Improved_response.text}\n {"-"*30}')
# Out:
# AI Response With improved prompt:
#  ------------------------------
# To give you the best option, choose the one that fits your situation:
#
# ### Option 1: Sick Leave (General)
# "Hi [Manager's Name], I’m writing to let you know that I’m feeling unwell today and will need to take a sick day. I plan to be back online tomorrow, but I will keep you posted if anything changes. Thanks for understanding."
#
# ### Option 2: Family/Personal Emergency
# "Hi [Manager's Name], please accept this message as notification that I have an unexpected personal emergency to attend to today. I apologize for the short notice and will make sure to catch up on my tasks as soon as I return. Thank you for your flexibility."
#
# ### Option 3: Appointment/Late Arrival
# "Hi [Manager's Name], I have a personal appointment this morning and will be logging on around [Time]. I am available via email/Slack if anything urgent comes up before then. Thank you."
#
# ### Option 4: Short and Professional (For minor delays)
# "Hi [Manager's Name], please excuse my absence today. I’ve come down with [a cold/something minor] and need to take the day to recover. I’ll be back at my desk tomorrow morning."
#
# **A few tips for sending these:**
# *   **Send it as early as possible:** The more notice you give, the more professional it looks.
# *
#  ------------------------------

# %% [markdown]
# ## Detailed Prompting

# %%
# Detailed Prompting

Detailed_prompt = "You are a professional employee. Write an excuse message to your manager, explaining that you will be late to work because of a family emergency,\
      and you will make up for the lost time by working extra hours this week." # Putting "Role", "Task", and "To Whom","Reason", and "Solution"

Detailed_response = client.models.generate_content(
    model='gemini-3.1-flash-lite',
    contents= Detailed_prompt,
    config=config
)

print(f'AI Response With detailed prompt:\n {"-"*30}\n{Detailed_response.text}\n {"-"*30}')
# Out:
# AI Response With detailed prompt:
#  ------------------------------
# Subject: Late arrival today - [Your Name]
#
# Hi [Manager's Name],
#
# Please accept my apologies, but I will be arriving late to work this morning due to an unexpected family emergency that requires my immediate attention.
#
# I anticipate being in by [Time you expect to arrive]. I am currently staying on top of my urgent tasks and will ensure that I make up for the missed hours by working late throughout the remainder of the week to stay on schedule.
#
# Thank you for your understanding. I will be online/in the office as soon as I possibly can.
#
# Best regards,
#
# [Your Name]
#  ------------------------------

# %% [markdown]
# ## Creative Prompt

# %%
# Creative Prompting

# Putting "Role", "Task", and "To Whom","Reason", "Solution", and "Tone" in the prompt to make it more creative and empathetic. 
Creative_prompt = "You are a professional employee. Write an excuse message to your manager, explaining that you will be late to work because of a family emergency,\
      and you will make up for the lost time by working extra hours this week. You need to be more empathetic and talking like you harry up with some mistaypes that represnt your anixity."

Creative_response = client.models.generate_content(
    model='gemini-3.1-flash-lite',
    contents= Creative_prompt,
    config=config
)

print(f'AI Response With creative prompt:\n {"-"*30}\n{Creative_response.text}\n {"-"*30}')
# Out:
# AI Response With creative prompt:
#  ------------------------------
# Hi [Manager's Name],
#
# I am so sorry to reach out like this, but I have a bit of a family emergency that just popped up this morning and I am scrambling to get it sorted out. I’m really stressed about it but I am trying to move as fast as I can to get there.
#
# I am running late and wont be in until a little bit later this morning. Please know I am so sorry for the inconvenience and I promise to make up all the lost time by staying late every evening this week to get everything caught up.
#
# I am hurrying as fast as I can now—I will be there as soon as physically possible. Thanks for understanding, I’m just really worried about my family right now.
#
# Best,
#
# [Your Name]
#  ------------------------------

# %% [markdown]
# ## Prompting with clear constraints

# %%
# Prompting with clear constraints

const_prompt = "You are a professional employee. Write an excuse message to your manager, explaining that you will be late to work because of a family emergency,\
      and you will make up for the lost time by working extra hours this week. Addionly, you need to make it only with 50 words, and it should be polite and professional witout be anxious."

# Putting "Role", "Task", and "To Whom","Reason", "Solution", and "Constraints" 

const_response = client.models.generate_content(
    model='gemini-3.1-flash-lite',
    contents= const_prompt,
    config=config
)

print(f'AI response with clear constraints prompt:\n {"-"*30}\n{const_response.text}\n {"-"*30}')
# Out:
# AI response with clear constraints prompt:
#  ------------------------------
# Dear [Manager's Name],
#
# Please accept my apologies, but I will be arriving late to the office today due to an unexpected family emergency. I am currently addressing the situation and expect to be in by [Time]. I will make up the missed hours throughout the remainder of this week. Thank you.
#  ------------------------------
